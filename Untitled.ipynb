# %%
pip install -r requirements.txt
# Out:
# ...
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/30.3 MB ? eta -:--:--
# ...

# %%
docker compose up
# Out:
#   Cell In[2], line 1
#     docker compose up
#            ^
# SyntaxError: invalid syntax

# %%
python train.py
# Out:
#   Cell In[3], line 1
#     python train.py
#            ^
# SyntaxError: invalid syntax
